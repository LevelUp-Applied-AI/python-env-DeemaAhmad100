# %%
import pandas as pd

# %%
df=pd_read_csv = pd.read_csv("sample.csv")

# %%
print("Shape:", df.shape)
# Out:
# Shape: (4, 4)

# %%
print(df.head())
print(df.describe())
# Out:
#    name    Age   Salary     position
# 0  Ali      65         700   retired
# 1  omar     53         800    Doctor
# 2  Asem     40         500     Nurse
# 3  Salem    44         600  Engineer
#              Age   Salary
# count   4.000000    4.000000
# mean   50.500000  650.000000
# std    11.090537  129.099445
# min    40.000000  500.000000
# 25%    43.000000  575.000000
# 50%    48.500000  650.000000
# 75%    56.000000  725.000000
# max    65.000000  800.000000
